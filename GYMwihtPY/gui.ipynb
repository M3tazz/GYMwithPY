# %%
import tkinter as tk
from PIL import Image, ImageTk

# Create the main window
root = tk.Tk()
root.title("Fitness App")

# Load images (replace with actual file paths)
after_selfie_image = Image.open("after_selfie.png")
after_selfie_photo = ImageTk.PhotoImage(after_selfie_image)

core_strength_image = Image.open("core_strength.png")
core_strength_photo = ImageTk.PhotoImage(core_strength_image)

# Create widgets
label_after_selfie = tk.Label(root, image=after_selfie_photo)
label_after_selfie.pack()

button_quit = tk.Button(root, text="Quit", command=root.quit)
button_quit.pack()

label_core_strength = tk.Label(root, image=core_strength_photo)
label_core_strength.pack()

# Start the GUI loop
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 9
#       6 root.title("Fitness App")
#       8 # Load images (replace with actual file paths)
# ----> 9 after_selfie_image = Image.open("after_selfie.png")
#      10 after_selfie_photo = ImageTk.PhotoImage(after_selfie_image)
#      12 core_strength_image = Image.open("core_strength.png")
#
# File c:\Users\Menna Elwan\AppData\Local\Programs\Python\Python312\Lib\site-packages\PIL\Image.py:3431, in open(fp, mode, formats)
#    3428     filename = os.path.realpath(os.fspath(fp))
#    3430 if filename:
# -> 3431     fp = builtins.open(filename, "rb")
#    3432     exclusive_fp = True
#    3433 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Collage\\Paython\\Work\\after_selfie.png'

# %%
from tkinter import *

def main():
    root = Tk()
    root.title("Simple Calculator")
    root.geometry("300x200")

    entry = Entry(root, width=20, borderwidth=5)
    entry.grid(row=0, column=0, columnspan=4, padx=10, pady=10)

    def button_click(number):
        current = entry.get()
        new_current = current + str(number)
        entry.delete(0, END)
        entry.insert(0, new_current)

    def button_clear():
        entry.delete(0, END)

    def button_add():
        global first_number
        global operator
        first_number = float(entry.get())
        operator = "+"
        entry.delete(0, END)

    def button_equal():
        global first_number
        global operator
        second_number = float(entry.get())
        if operator == "+":
            result = first_number + second_number
        elif operator == "-":
            result = first_number - second_number
        elif operator == "*":
            result = first_number * second_number
        elif operator == "/":
            result = first_number / second_number
        entry.delete(0, END)
        entry.insert(0, result)

    def button_subtract():
        global first_number
        global operator
        first_number = float(entry.get())
        operator = "-"
        entry.delete(0, END)

    def button_multiply():
        global first_number
        global operator
        first_number = float(entry.get())
        operator = "*"
        entry.delete(0, END)

    def button_divide():
        global first_number
        global operator
        first_number = float(entry.get())
        operator = "/"
        entry.delete(0, END)

    button_1 = Button(root, text="1", padx=40, pady=20, command=lambda: button_click(1))
    button_2 = Button(root, text="2", padx=40, pady=20, command=lambda: button_click(2))
    button_3 = Button(root, text="3", padx=40, pady=20, command=lambda: button_click(3))
    button_4 = Button(root, text="4", padx=40, pady=20, command=lambda: button_click(4))
    button_5 = Button(root, text="5", padx=40, pady=20, command=lambda: button_click(5))
    button_6 = Button(root, text="6", padx=40, pady=20, command=lambda: button_click(6))
    button_7 = Button(root, text="7", padx=40, pady=20, command=lambda: button_click(7))
    button_8 = Button(root, text="8", padx=40, pady=20, command=lambda: button_click(8))
    button_9 = Button(root, text="9", padx=40, pady=20, command=lambda: button_click(9))
    button_0 = Button(root, text="0", padx=40, pady=20, command=lambda: button_click(0))
    button_add = Button(root, text="+", padx=39, pady=20, command=button_add)
    button_subtract = Button(root, text="-", padx=41, pady=20, command=button_subtract)
    button_multiply = Button(root, text="*", padx=41, pady=20, command=button_multiply)
    button_divide = Button(root, text="/", padx=41, pady=20, command=button_divide)
    button_equal = Button(root, text="=", padx=40, pady=20, command=button_equal)
    button_clear = Button(root, text="Clear", padx=80, pady=20, command=button_clear)

    button_1.grid(row=3, column=0)
    button_2.grid(row=3, column=1)
    button_3.grid(row=3, column=2)
    button_4.grid(row=2, column=0)
    button_5.grid(row=2, column=1)
    button_6.grid(row=2, column=2)
    button_7.grid(row=1, column=0)
    button_8.grid(row=1, column=1)
    button_9.grid(row=1, column=2)
    button_0.grid(row=4, column=0)
    button_add.grid(row=5, column=0)
    button_subtract.grid(row=5, column=1)
    button_multiply.grid(row=5, column=2)
    button_divide.grid(row=5, column=3)
    button_equal.grid(row=6, column=1)
    button_clear.grid(row=6, column=2, columnspan=2)

    root.mainloop()

if __name__ == "__main__":
    main()

# %%
from tkinter import *


root = Tk()
root.title("First Gui")
root.geometry("500x200")        
root.mainloop()#loop for the main loop

# %% [markdown]
# from tkinter import *
#
# def main():
#     root = Tk()
#     root.title("Simple Calculator")
#     root.geometry("300x200")
#     entry = Entry(root, width=20, borderwidth=5)
#     entry.grid(row=0, column=0, columnspan=4, padx=10, pady=10)
#
#     def button_click(number):
#     current = entry.get()   if current is not None else None
#     new_current = current + str(number) if current is not None else str(number)
#     entry.delete(0, END)
#     entry.insert(0, new_current)
#
#     def button_clear():
#     entry.delete(0, END)
#
#     def button_add():
#     global first_number
#     first_number = float(entry.get())
#     operator = "+"
#     entry.delete(0, END)
#
#     def button_equal():
#     global first_number
#     second_number = float(entry.get())
#     if operator == "+":
#     result = first_number + second_number
#     elif operator == "-":
#     result = first_number - second_number
#     elif operator == "*":
#     result = first_number * second_number
#     elif operator == "/":
#     result = first_number / second_number
#     entry.delete(0, END)
#     entry.insert(0, result)
#
#     def button_subtract():
#     global first_number
#     first_number = float(entry.get())
#     operator = "-"
#     entry.delete(0, END)
#
#     def button_multiply():
#     global first_number
#     first_number = float(entry.get())
#     operator = "*"
#     entry.delete(0, END)
#
#     def button_divide():
#     global first_number
#     first_number = float(entry.get())
#     operator = "/"
#     entry.delete(0, END)
#
#     button_1 = Button(root, text="1", padx=40, pady=20, command=lambda: button_click(1))
#     button_2 = Button(root, text="2", padx=40, pady=20, command=lambda: button_click(2))
#     button_3 = Button(root, text="3", padx=40, pady=20, command=lambda: button_click(3))
#     button_4 = Button(root, text="4", padx=40, pady=20, command=lambda: button_click(4))
#     button_5 = Button(root, text="5", padx=40, pady=20, command=lambda: button_click(5))
#     button_6 = Button(root, text="6", padx=40, pady=20, command=lambda: button_click(6))
#     button_7 = Button(root, text="7", padx=40, pady=20, command=lambda: button_click(7))
#     button_8 = Button(root, text="8", padx=40, pady=20, command=lambda: button_click(8))
#     button_9 = Button(root, text="9", padx=40, pady=20, command=lambda: button_click(9))
#     button_0 = Button(root, text="0", padx=40, pady=20, command=lambda: button_click(0))
#     button_add = Button(root, text="+", padx=39, pady=20, command=button_add)
#     button_subtract = Button(root, text="-", padx=41, pady=20, command=button_subtract)
#     button_multiply = Button(root, text="*", padx=41, pady=20, command=button_multiply)
#     button_divide = Button(root, text="/", padx=41, pady=20, command=button_divide)
#     button_equal = Button(root, text="=", padx=40, pady=20, command=button_equal)
#     button_clear = Button(root, text="Clear", padx=80, pady=20, command=button_clear)
#
#     button_1.grid(row=3, column=0)
#     button_2.grid(row=3, column=1)
#     button_3.grid(row=3, column=2)
#
#     button_4.grid(row=2, column=0)
#     button_5.grid(row=2, column=1)
#     button_6.grid(row=2, column=2)
#
#     button_7.grid(row=1, column=0)
#     button_8.grid(row=1, column=1)
#     button_9.grid(row=1, column=2)
#
#     button_0.grid(row=4, column=0)
#     button_add.grid(row=5, column=0)
#     button_subtract.grid(row=5, column=1)
#     button_multiply.grid(row=5, column=2)
#     button_divide.grid(row=5, column=3)
#     button_equal.grid(row=6, column=1)
#     button_clear.grid(row=6, column=2, columnspan=2)
#
#     root.mainloop()
